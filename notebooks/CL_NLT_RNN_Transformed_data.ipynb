# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
# Load the raw npz file
raw_data = np.load('../data/transformed_simulation_data.npz')
z_vals = raw_data['z_vals']
u_plot = raw_data['u_plot']

# z_vals contains [Rel Pos, Rel Vel, Abs Pos of M2, Abs Vel of M2]
columns = ['Input Force (u)', 'Rel Pos (z1)', 'Rel Vel (z2)', 'Abs Pos of M2 (z3)', 'Abs Vel of M2 (z4)']

# Create a DataFrame combining both raw arrays
# We use np.column_stack to attach the 1D u_plot alongside the 2D z_vals
df = pd.DataFrame(
    np.column_stack((u_plot, z_vals)),
    columns=columns
)

# Set the index name to represent Time Steps
df.index.name = 'Time Step'
display(df.head(10))
# Out:
#            Input Force (u)  Rel Pos (z1)  Rel Vel (z2)  Abs Pos of M2 (z3)  \
# Time Step
# 0                 0.993428      0.000000      0.000000        0.000000e+00
# 1                 0.993428      0.000196      0.039080        6.578013e-07
# 2                 0.993428      0.000777      0.076865        5.227087e-06
# 3                 0.993428      0.001730      0.113386        1.752287e-05
# 4                 0.993428      0.003041      0.148670        4.125689e-05
# 5                 0.993428      0.004699      0.182746        8.003968e-05
# 6                 0.993428      0.006692      0.215643        1.373827e-04
# 7                 0.993428      0.009008      0.247386        2.167003e-04
# 8                 0.993428      0.011636      0.278003        3.213117e-04
# 9                 0.993428      0.014564      0.307520        4.544431e-04
#
#            Abs Vel of M2 (z4)
# Time Step
# 0                    0.000000
# 1                    0.000197
# 2                    0.000781
# 3                    0.001740
# 4                    0.003066
# 5                    0.004749
# 6                    0.006777
# 7                    0.009142
# 8                    0.011834
# 9                    0.014844

# %%
def deadzone_numpy(z, delta):
    """Creates a physical deadzone. Outputs 0 when within the delta threshold."""
    positive_slip = np.maximum(0, z - delta)
    negative_slip = -np.maximum(0, -z - delta)
    return positive_slip + negative_slip

delta_physical = 1.0

# Create the new y states by wrapping z1 (relative position)
y_vals = np.copy(z_vals)
y_vals[:, 0] = deadzone_numpy(z_vals[:, 0], delta_physical)

# normalize the data 
y_mean, y_std = y_vals.mean(axis=0), y_vals.std(axis=0)
u_mean, u_std = u_plot.mean(), u_plot.std()

y_norm = (y_vals - y_mean) / (y_std + 1e-8)
u_norm = (u_plot - u_mean) / (u_std + 1e-8)

# convert to torch tensors
Y = torch.tensor(y_norm, dtype=torch.float32)
U = torch.tensor(u_norm, dtype=torch.float32).unsqueeze(1)

print(f"Data is normalized. Final shapes ready for model:")
print(f"Y Shape: {Y.shape} | U Shape: {U.shape}")
# Out:
# Data is normalized. Final shapes ready for model:
# Y Shape: torch.Size([20000, 4]) | U Shape: torch.Size([20000, 1])

# %%
# define the model
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        
        # Memory Update Weights
        self.W_hh = nn.Parameter(torch.randn(hidden_size, hidden_size) * 0.1)
        self.W_uh = nn.Parameter(torch.randn(input_size, hidden_size) * 0.1)
        self.b_h = nn.Parameter(torch.zeros(hidden_size))
        
        # State Prediction Weights
        self.W_hx = nn.Parameter(torch.randn(hidden_size, output_size) * 0.1)
        self.b_x = nn.Parameter(torch.zeros(output_size))
    
    def forward(self, combined_u_seq):
        # get sequence length
        seq_len = combined_u_seq.shape[0]

        # initialize hidden state
        h_k = torch.zeros(self.hidden_size, device=combined_u_seq.device)

        # initialize list to store predictions
        y_pred = []

        # loop through the sequence
        for k in range(seq_len):
            # contains [x1, v1, x2, v2, force]
            step_data = combined_u_seq[k]

            # update hidden state
            h_k = torch.relu(h_k @ self.W_hh + step_data @ self.W_uh + self.b_h)

            # predict next state
            y_k = h_k @ self.W_hx + self.b_x

            # store prediction
            y_pred.append(y_k)

        # convert list to tensor
        y_pred = torch.stack(y_pred)

        return y_pred

# %% [markdown]
# # Training with `hidden_size=64` and `seq_len=100`. Also lowered learning rate to 0.0001 and applied gradient clipping

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Training on: {device}")

# train the model
model = RNN(input_size=5, hidden_size=64, output_size=4).to(device) # changed this to 5 (4 current states + 1 input force)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# training loop
n_epochs = 1000
seq_len = 100

loss_history = []

batch_size = 16

for epoch in range(n_epochs):
    # zero the gradients
    optimizer.zero_grad()
    
    batch_loss = 0

    for _ in range(batch_size):
        # Pick a random starting point in the sequence
        start_idx = np.random.randint(0, len(U) - seq_len - 1) # -1 cuz we need more space to get the traget one step in the future
        end_idx = start_idx + seq_len
        
        # Get current states and inputs
        U_curr = U[start_idx:end_idx].to(device)
        Y_curr = Y[start_idx:end_idx].to(device)
        
        # combine current state and input 
        combined_input = torch.cat((Y_curr, U_curr), dim=1)

        # NEW: get next states (target shifted by +1)
        Y_target = Y[start_idx + 1: end_idx + 1].to(device)

        # forward pass
        Y_pred_chunk = model(combined_input)
        
        # calculate loss
        loss = criterion(Y_pred_chunk, Y_target)
        loss = loss/batch_size
        
        # backpropagate and update
        loss.backward()
        batch_loss += (loss.item() * batch_size)
        
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
    optimizer.step()

    loss_history.append(loss.item())
    
    # print the loss every 10 epochs
    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch+1}/{n_epochs}, Average Batch Loss: {batch_loss / batch_size:.4f}")
# Out:
# Training on: cuda
# Epoch 10/1000, Average Batch Loss: 1.0231
# Epoch 20/1000, Average Batch Loss: 0.5673
# Epoch 30/1000, Average Batch Loss: 0.5242
# Epoch 40/1000, Average Batch Loss: 1.1633
# Epoch 50/1000, Average Batch Loss: 0.8995
# Epoch 60/1000, Average Batch Loss: 0.9463
# Epoch 70/1000, Average Batch Loss: 1.2683
# Epoch 80/1000, Average Batch Loss: 0.8805
# Epoch 90/1000, Average Batch Loss: 0.7697
# Epoch 100/1000, Average Batch Loss: 0.8265
# Epoch 110/1000, Average Batch Loss: 0.5271
# Epoch 120/1000, Average Batch Loss: 0.7663
# Epoch 130/1000, Average Batch Loss: 0.5842
# Epoch 140/1000, Average Batch Loss: 0.7959
# Epoch 150/1000, Average Batch Loss: 0.5373
# Epoch 160/1000, Average Batch Loss: 0.4293
# Epoch 170/1000, Average Batch Loss: 0.4189
# Epoch 180/1000, Average Batch Loss: 0.3883
# Epoch 190/1000, Average Batch Loss: 0.4270
# Epoch 200/1000, Average Batch Loss: 0.1687
# Epoch 210/1000, Average Batch Loss: 0.3075
# Epoch 220/1000, Average Batch Loss: 0.1140
# Epoch 230/1000, Average Batch Loss: 0.2661
# Epoch 240/1000, Average Batch Loss: 0.1971
# Epoch 250/1000, Average Batch Loss: 0.1210
# Epoch 260/1000, Average Batch Loss: 0.0493
# Epoch 270/1000, Average Batch Loss: 0.1162
# Epoch 280/1000, Average Batch Loss: 0.1018
# Epoch 290/1000, Average Batch Loss: 0.1799
# Epoch 300/1000, Average Batch Loss: 0.0873
# Epoch 310/1000, Average Batch Loss: 0.1264
# Epoch 320/1000, Average Batch Loss: 0.1525
# Epoch 330/1000, Average Batch Loss: 0.1048
# Epoch 340/1000, Average Batch Loss: 0.1685
# Epoch 350/1000, Average Batch Loss: 0.1709
# Epoch 360/1000, Average Batch Loss: 0.1694
# Epoch 370/1000, Average Batch Loss: 0.0835
# Epoch 380/1000, Average Batch Loss: 0.0838
# Epoch 390/1000, Average Batch Loss: 0.0425
# Epoch 400/1000, Average Batch Loss: 0.0980
# Epoch 410/1000, Average Batch Loss: 0.0529
# Epoch 420/1000, Average Batch Loss: 0.1061
# Epoch 430/1000, Average Batch Loss: 0.0827
# Epoch 440/1000, Average Batch Loss: 0.0996
# Epoch 450/1000, Average Batch Loss: 0.0908
# Epoch 460/1000, Average Batch Loss: 0.0436
# Epoch 470/1000, Average Batch Loss: 0.0829
# Epoch 480/1000, Average Batch Loss: 0.0776
# Epoch 490/1000, Average Batch Loss: 0.0384
# Epoch 500/1000, Average Batch Loss: 0.0999
# Epoch 510/1000, Average Batch Loss: 0.0369
# Epoch 520/1000, Average Batch Loss: 0.0847
# Epoch 530/1000, Average Batch Loss: 0.0768
# Epoch 540/1000, Average Batch Loss: 0.0626
# Epoch 550/1000, Average Batch Loss: 0.0787
# Epoch 560/1000, Average Batch Loss: 0.0613
# Epoch 570/1000, Average Batch Loss: 0.0412
# Epoch 580/1000, Average Batch Loss: 0.0428
# Epoch 590/1000, Average Batch Loss: 0.0778
# Epoch 600/1000, Average Batch Loss: 0.0722
# Epoch 610/1000, Average Batch Loss: 0.0242
# Epoch 620/1000, Average Batch Loss: 0.0767
# Epoch 630/1000, Average Batch Loss: 0.0564
# Epoch 640/1000, Average Batch Loss: 0.0433
# Epoch 650/1000, Average Batch Loss: 0.0343
# Epoch 660/1000, Average Batch Loss: 0.0439
# Epoch 670/1000, Average Batch Loss: 0.0663
# Epoch 680/1000, Average Batch Loss: 0.0503
# Epoch 690/1000, Average Batch Loss: 0.0425
# Epoch 700/1000, Average Batch Loss: 0.0481
# Epoch 710/1000, Average Batch Loss: 0.0517
# Epoch 720/1000, Average Batch Loss: 0.0405
# Epoch 730/1000, Average Batch Loss: 0.0308
# Epoch 740/1000, Average Batch Loss: 0.0307
# Epoch 750/1000, Average Batch Loss: 0.0341
# Epoch 760/1000, Average Batch Loss: 0.0232
# Epoch 770/1000, Average Batch Loss: 0.0310
# Epoch 780/1000, Average Batch Loss: 0.0414
# Epoch 790/1000, Average Batch Loss: 0.0386
# Epoch 800/1000, Average Batch Loss: 0.0321
# Epoch 810/1000, Average Batch Loss: 0.0284
# Epoch 820/1000, Average Batch Loss: 0.0363
# Epoch 830/1000, Average Batch Loss: 0.0300
# Epoch 840/1000, Average Batch Loss: 0.0352
# Epoch 850/1000, Average Batch Loss: 0.0323
# Epoch 860/1000, Average Batch Loss: 0.0338
# Epoch 870/1000, Average Batch Loss: 0.0348
# Epoch 880/1000, Average Batch Loss: 0.0456
# Epoch 890/1000, Average Batch Loss: 0.0298
# Epoch 900/1000, Average Batch Loss: 0.0309
# Epoch 910/1000, Average Batch Loss: 0.0290
# Epoch 920/1000, Average Batch Loss: 0.0173
# Epoch 930/1000, Average Batch Loss: 0.0298
# Epoch 940/1000, Average Batch Loss: 0.0313
# Epoch 950/1000, Average Batch Loss: 0.0353
# Epoch 960/1000, Average Batch Loss: 0.0177
# Epoch 970/1000, Average Batch Loss: 0.0217
# Epoch 980/1000, Average Batch Loss: 0.0239
# Epoch 990/1000, Average Batch Loss: 0.0504
# Epoch 1000/1000, Average Batch Loss: 0.0273

# %%
# Plot the Learning Curve
plt.figure(figsize=(10, 5))

# Plot the saved list
plt.plot(loss_history, color='blue')
plt.title('RNN Training Loss Over Time for size 64')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (Loss)')
plt.grid(True)
plt.show()

# %%
# evaluate the model
print("Evaluating trained RNN in Closed-Loop Autoregressive for Size 64")
model.eval()

with torch.no_grad():
    continous_pred = []
    current_state = Y[0].to(device)

    # init hidden memory for all 20,000 steps
    h_k = torch.zeros(model.hidden_size, device=device)

    for k in range(len(U)):
        # get true input for this time step
        u_k = U[k].to(device)

        # combine current input with current force
        step_data = torch.cat((current_state, u_k))

        # forward pass this time step
        h_k = torch.relu(h_k @ model.W_hh + step_data @ model.W_uh + model.b_h)
        next_state_pred = h_k @ model.W_hx + model.b_x

        # save this prediction
        continous_pred.append(next_state_pred)

        # feedback loop
        current_state = next_state_pred

    Y_pred_norm = torch.stack(continous_pred)
    # Convert to numpy and un-normalize
    Y_pred = Y_pred_norm.cpu().numpy() * y_std + y_mean

# Plotting Results
plt.figure(figsize=(12, 8))

# Plot Rel Pos (z1)
plt.subplot(2, 1, 1)
plt.plot(y_vals[:, 0], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 0], 'r--', label='RNN Prediction')
plt.ylabel('Relative Position z1 (x1 - x2) (m)')
plt.legend()
plt.grid(True)

# Plot Absolute Position of M2 (z3)
plt.subplot(2, 1, 2)
plt.plot(y_vals[:, 2], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 2], 'g--', label='RNN Prediction')
plt.ylabel('Absolute Position of M2 (m)')
plt.xlabel('Time Steps')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Evaluating trained RNN in Closed-Loop Autoregressive for Size 64

# %% [markdown]
# # Try with same epochs (1000) but different hidden size (4)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Training on: {device}")

# train the model
model = RNN(input_size=5, hidden_size=4, output_size=4).to(device) # changed this to 5 (4 current states + 1 input force)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# training loop
n_epochs = 1000
seq_len = 100

loss_history = []

batch_size = 16

for epoch in range(n_epochs):
    # zero the gradients
    optimizer.zero_grad()
    
    batch_loss = 0

    for _ in range(batch_size):
        # Pick a random starting point in the sequence
        start_idx = np.random.randint(0, len(U) - seq_len - 1) # -1 cuz we need more space to get the traget one step in the future
        end_idx = start_idx + seq_len
        
        # Get current states and inputs
        U_curr = U[start_idx:end_idx].to(device)
        Y_curr = Y[start_idx:end_idx].to(device)
        
        # combine current state and input 
        combined_input = torch.cat((Y_curr, U_curr), dim=1)

        # NEW: get next states (target shifted by +1)
        Y_target = Y[start_idx + 1: end_idx + 1].to(device)

        # forward pass
        Y_pred_chunk = model(combined_input)
        
        # calculate loss
        loss = criterion(Y_pred_chunk, Y_target)
        loss = loss/batch_size
        
        # backpropagate and update
        loss.backward()
        batch_loss += (loss.item() * batch_size)
        
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
    optimizer.step()

    loss_history.append(loss.item())
    
    # print the loss every 10 epochs
    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch+1}/{n_epochs}, Average Batch Loss: {batch_loss / batch_size:.4f}")
# Out:
# Training on: cuda
# Epoch 10/1000, Average Batch Loss: 0.7718
# Epoch 20/1000, Average Batch Loss: 1.2686
# Epoch 30/1000, Average Batch Loss: 0.8897
# Epoch 40/1000, Average Batch Loss: 0.5308
# Epoch 50/1000, Average Batch Loss: 0.4423
# Epoch 60/1000, Average Batch Loss: 0.9395
# Epoch 70/1000, Average Batch Loss: 1.1857
# Epoch 80/1000, Average Batch Loss: 1.5460
# Epoch 90/1000, Average Batch Loss: 1.7264
# Epoch 100/1000, Average Batch Loss: 1.0990
# Epoch 110/1000, Average Batch Loss: 1.3017
# Epoch 120/1000, Average Batch Loss: 1.0953
# Epoch 130/1000, Average Batch Loss: 1.4040
# Epoch 140/1000, Average Batch Loss: 0.6030
# Epoch 150/1000, Average Batch Loss: 0.8224
# Epoch 160/1000, Average Batch Loss: 0.7031
# Epoch 170/1000, Average Batch Loss: 1.1574
# Epoch 180/1000, Average Batch Loss: 0.5927
# Epoch 190/1000, Average Batch Loss: 0.4655
# Epoch 200/1000, Average Batch Loss: 0.8301
# Epoch 210/1000, Average Batch Loss: 1.2481
# Epoch 220/1000, Average Batch Loss: 0.6911
# Epoch 230/1000, Average Batch Loss: 0.5236
# Epoch 240/1000, Average Batch Loss: 1.4033
# Epoch 250/1000, Average Batch Loss: 0.4573
# Epoch 260/1000, Average Batch Loss: 1.1930
# Epoch 270/1000, Average Batch Loss: 0.6657
# Epoch 280/1000, Average Batch Loss: 1.0882
# Epoch 290/1000, Average Batch Loss: 1.5590
# Epoch 300/1000, Average Batch Loss: 1.0890
# Epoch 310/1000, Average Batch Loss: 0.8825
# Epoch 320/1000, Average Batch Loss: 0.7437
# Epoch 330/1000, Average Batch Loss: 0.9780
# Epoch 340/1000, Average Batch Loss: 0.9657
# Epoch 350/1000, Average Batch Loss: 0.5427
# Epoch 360/1000, Average Batch Loss: 0.7298
# Epoch 370/1000, Average Batch Loss: 0.9454
# Epoch 380/1000, Average Batch Loss: 0.8282
# Epoch 390/1000, Average Batch Loss: 0.5286
# Epoch 400/1000, Average Batch Loss: 0.6463
# Epoch 410/1000, Average Batch Loss: 1.0634
# Epoch 420/1000, Average Batch Loss: 1.0282
# Epoch 430/1000, Average Batch Loss: 0.7298
# Epoch 440/1000, Average Batch Loss: 0.7179
# Epoch 450/1000, Average Batch Loss: 1.0105
# Epoch 460/1000, Average Batch Loss: 1.1712
# Epoch 470/1000, Average Batch Loss: 1.0772
# Epoch 480/1000, Average Batch Loss: 0.5630
# Epoch 490/1000, Average Batch Loss: 0.5472
# Epoch 500/1000, Average Batch Loss: 0.7553
# Epoch 510/1000, Average Batch Loss: 0.9793
# Epoch 520/1000, Average Batch Loss: 1.5533
# Epoch 530/1000, Average Batch Loss: 0.7559
# Epoch 540/1000, Average Batch Loss: 1.2118
# Epoch 550/1000, Average Batch Loss: 0.9870
# Epoch 560/1000, Average Batch Loss: 0.7217
# Epoch 570/1000, Average Batch Loss: 0.7911
# Epoch 580/1000, Average Batch Loss: 0.9176
# Epoch 590/1000, Average Batch Loss: 1.4662
# Epoch 600/1000, Average Batch Loss: 1.4067
# Epoch 610/1000, Average Batch Loss: 0.4611
# Epoch 620/1000, Average Batch Loss: 0.8780
# Epoch 630/1000, Average Batch Loss: 0.8145
# Epoch 640/1000, Average Batch Loss: 0.6940
# Epoch 650/1000, Average Batch Loss: 1.2354
# Epoch 660/1000, Average Batch Loss: 0.5155
# Epoch 670/1000, Average Batch Loss: 0.7115
# Epoch 680/1000, Average Batch Loss: 0.7544
# Epoch 690/1000, Average Batch Loss: 0.7586
# Epoch 700/1000, Average Batch Loss: 1.0327
# Epoch 710/1000, Average Batch Loss: 0.8306
# Epoch 720/1000, Average Batch Loss: 0.7216
# Epoch 730/1000, Average Batch Loss: 0.7240
# Epoch 740/1000, Average Batch Loss: 0.7577
# Epoch 750/1000, Average Batch Loss: 1.1681
# Epoch 760/1000, Average Batch Loss: 1.1038
# Epoch 770/1000, Average Batch Loss: 0.8041
# Epoch 780/1000, Average Batch Loss: 0.7488
# Epoch 790/1000, Average Batch Loss: 0.5737
# Epoch 800/1000, Average Batch Loss: 1.0462
# Epoch 810/1000, Average Batch Loss: 0.5012
# Epoch 820/1000, Average Batch Loss: 0.6969
# Epoch 830/1000, Average Batch Loss: 0.4151
# Epoch 840/1000, Average Batch Loss: 0.6852
# Epoch 850/1000, Average Batch Loss: 0.9455
# Epoch 860/1000, Average Batch Loss: 0.6646
# Epoch 870/1000, Average Batch Loss: 0.8290
# Epoch 880/1000, Average Batch Loss: 1.0575
# Epoch 890/1000, Average Batch Loss: 0.6338
# Epoch 900/1000, Average Batch Loss: 0.9335
# Epoch 910/1000, Average Batch Loss: 1.1747
# Epoch 920/1000, Average Batch Loss: 0.8960
# Epoch 930/1000, Average Batch Loss: 0.7918
# Epoch 940/1000, Average Batch Loss: 0.6453
# Epoch 950/1000, Average Batch Loss: 0.8371
# Epoch 960/1000, Average Batch Loss: 0.6638
# Epoch 970/1000, Average Batch Loss: 0.5548
# Epoch 980/1000, Average Batch Loss: 0.6977
# Epoch 990/1000, Average Batch Loss: 1.1153
# Epoch 1000/1000, Average Batch Loss: 0.7552

# %%
# Plot the Learning Curve
plt.figure(figsize=(10, 5))

# Plot the saved list
plt.plot(loss_history, color='blue')
plt.title('RNN Training Loss Over Time for size 4')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (Loss)')
plt.grid(True)
plt.show()

# %%
# evaluate the model
print("Evaluating trained RNN in Closed-Loop Autoregressive for Size 4")
model.eval()

with torch.no_grad():
    continous_pred = []
    current_state = Y[0].to(device)

    # init hidden memory for all 20,000 steps
    h_k = torch.zeros(model.hidden_size, device=device)

    for k in range(len(U)):
        # get true input for this time step
        u_k = U[k].to(device)

        # combine current input with current force
        step_data = torch.cat((current_state, u_k))

        # forward pass this time step
        h_k = torch.relu(h_k @ model.W_hh + step_data @ model.W_uh + model.b_h)
        next_state_pred = h_k @ model.W_hx + model.b_x

        # save this prediction
        continous_pred.append(next_state_pred)

        # feedback loop
        current_state = next_state_pred

    Y_pred_norm = torch.stack(continous_pred)
    # Convert to numpy and un-normalize
    Y_pred = Y_pred_norm.cpu().numpy() * y_std + y_mean

# Plotting Results
plt.figure(figsize=(12, 8))

# Plot Rel Pos (z1)
plt.subplot(2, 1, 1)
plt.plot(y_vals[:, 0], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 0], 'r--', label='RNN Prediction')
plt.ylabel('Relative Position z1 (x1 - x2) (m)')
plt.legend()
plt.grid(True)

# Plot Absolute Position of M2 (z3)
plt.subplot(2, 1, 2)
plt.plot(y_vals[:, 2], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 2], 'g--', label='RNN Prediction')
plt.ylabel('Absolute Position of M2 (m)')
plt.xlabel('Time Steps')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Evaluating trained RNN in Closed-Loop Autoregressive for Size 4

# %% [markdown]
# # Try with hidden size (8) and epochs (1000)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Training on: {device}")

# train the model
model = RNN(input_size=5, hidden_size=8, output_size=4).to(device) # changed this to 5 (4 current states + 1 input force)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# training loop
n_epochs = 1000
seq_len = 100

loss_history = []

batch_size = 16

for epoch in range(n_epochs):
    # zero the gradients
    optimizer.zero_grad()
    
    batch_loss = 0

    for _ in range(batch_size):
        # Pick a random starting point in the sequence
        start_idx = np.random.randint(0, len(U) - seq_len - 1) # -1 cuz we need more space to get the traget one step in the future
        end_idx = start_idx + seq_len
        
        # Get current states and inputs
        U_curr = U[start_idx:end_idx].to(device)
        Y_curr = Y[start_idx:end_idx].to(device)
        
        # combine current state and input 
        combined_input = torch.cat((Y_curr, U_curr), dim=1)

        # NEW: get next states (target shifted by +1)
        Y_target = Y[start_idx + 1: end_idx + 1].to(device)

        # forward pass
        Y_pred_chunk = model(combined_input)
        
        # calculate loss
        loss = criterion(Y_pred_chunk, Y_target)
        loss = loss/batch_size
        
        # backpropagate and update
        loss.backward()
        batch_loss += (loss.item() * batch_size)
        
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
    optimizer.step()

    loss_history.append(loss.item())
    
    # print the loss every 10 epochs
    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch+1}/{n_epochs}, Average Batch Loss: {batch_loss / batch_size:.4f}")
# Out:
# Training on: cuda
# Epoch 10/1000, Average Batch Loss: 0.8104
# Epoch 20/1000, Average Batch Loss: 0.6852
# Epoch 30/1000, Average Batch Loss: 0.5268
# Epoch 40/1000, Average Batch Loss: 1.0399
# Epoch 50/1000, Average Batch Loss: 0.8844
# Epoch 60/1000, Average Batch Loss: 0.8488
# Epoch 70/1000, Average Batch Loss: 0.9403
# Epoch 80/1000, Average Batch Loss: 1.1576
# Epoch 90/1000, Average Batch Loss: 1.6936
# Epoch 100/1000, Average Batch Loss: 1.0263
# Epoch 110/1000, Average Batch Loss: 0.8481
# Epoch 120/1000, Average Batch Loss: 1.1905
# Epoch 130/1000, Average Batch Loss: 0.8359
# Epoch 140/1000, Average Batch Loss: 0.7594
# Epoch 150/1000, Average Batch Loss: 0.9200
# Epoch 160/1000, Average Batch Loss: 1.2416
# Epoch 170/1000, Average Batch Loss: 0.6558
# Epoch 180/1000, Average Batch Loss: 0.6521
# Epoch 190/1000, Average Batch Loss: 1.0673
# Epoch 200/1000, Average Batch Loss: 0.7261
# Epoch 210/1000, Average Batch Loss: 1.2451
# Epoch 220/1000, Average Batch Loss: 0.9904
# Epoch 230/1000, Average Batch Loss: 0.7443
# Epoch 240/1000, Average Batch Loss: 1.2107
# Epoch 250/1000, Average Batch Loss: 1.1300
# Epoch 260/1000, Average Batch Loss: 1.1163
# Epoch 270/1000, Average Batch Loss: 1.2103
# Epoch 280/1000, Average Batch Loss: 0.7451
# Epoch 290/1000, Average Batch Loss: 0.7596
# Epoch 300/1000, Average Batch Loss: 1.0707
# Epoch 310/1000, Average Batch Loss: 0.8332
# Epoch 320/1000, Average Batch Loss: 1.2978
# Epoch 330/1000, Average Batch Loss: 0.9880
# Epoch 340/1000, Average Batch Loss: 0.8990
# Epoch 350/1000, Average Batch Loss: 0.9891
# Epoch 360/1000, Average Batch Loss: 1.0004
# Epoch 370/1000, Average Batch Loss: 0.7281
# Epoch 380/1000, Average Batch Loss: 0.5402
# Epoch 390/1000, Average Batch Loss: 0.7433
# Epoch 400/1000, Average Batch Loss: 0.6529
# Epoch 410/1000, Average Batch Loss: 0.9430
# Epoch 420/1000, Average Batch Loss: 1.2092
# Epoch 430/1000, Average Batch Loss: 0.8566
# Epoch 440/1000, Average Batch Loss: 0.9556
# Epoch 450/1000, Average Batch Loss: 0.7473
# Epoch 460/1000, Average Batch Loss: 1.0677
# Epoch 470/1000, Average Batch Loss: 0.4807
# Epoch 480/1000, Average Batch Loss: 1.1072
# Epoch 490/1000, Average Batch Loss: 0.8852
# Epoch 500/1000, Average Batch Loss: 0.6112
# Epoch 510/1000, Average Batch Loss: 0.6941
# Epoch 520/1000, Average Batch Loss: 1.0642
# Epoch 530/1000, Average Batch Loss: 0.8748
# Epoch 540/1000, Average Batch Loss: 1.0661
# Epoch 550/1000, Average Batch Loss: 1.0552
# Epoch 560/1000, Average Batch Loss: 0.7805
# Epoch 570/1000, Average Batch Loss: 0.5271
# Epoch 580/1000, Average Batch Loss: 0.5610
# Epoch 590/1000, Average Batch Loss: 1.0481
# Epoch 600/1000, Average Batch Loss: 0.7459
# Epoch 610/1000, Average Batch Loss: 0.8470
# Epoch 620/1000, Average Batch Loss: 0.9840
# Epoch 630/1000, Average Batch Loss: 0.7058
# Epoch 640/1000, Average Batch Loss: 1.1618
# Epoch 650/1000, Average Batch Loss: 0.6508
# Epoch 660/1000, Average Batch Loss: 0.6096
# Epoch 670/1000, Average Batch Loss: 0.5177
# Epoch 680/1000, Average Batch Loss: 0.6206
# Epoch 690/1000, Average Batch Loss: 0.3326
# Epoch 700/1000, Average Batch Loss: 0.9742
# Epoch 710/1000, Average Batch Loss: 0.7315
# Epoch 720/1000, Average Batch Loss: 0.6265
# Epoch 730/1000, Average Batch Loss: 0.9181
# Epoch 740/1000, Average Batch Loss: 0.7412
# Epoch 750/1000, Average Batch Loss: 0.4349
# Epoch 760/1000, Average Batch Loss: 0.7074
# Epoch 770/1000, Average Batch Loss: 0.7403
# Epoch 780/1000, Average Batch Loss: 0.8549
# Epoch 790/1000, Average Batch Loss: 0.3659
# Epoch 800/1000, Average Batch Loss: 0.3865
# Epoch 810/1000, Average Batch Loss: 0.8604
# Epoch 820/1000, Average Batch Loss: 0.8342
# Epoch 830/1000, Average Batch Loss: 0.3860
# Epoch 840/1000, Average Batch Loss: 0.9469
# Epoch 850/1000, Average Batch Loss: 0.3609
# Epoch 860/1000, Average Batch Loss: 0.8110
# Epoch 870/1000, Average Batch Loss: 0.5893
# Epoch 880/1000, Average Batch Loss: 0.5015
# Epoch 890/1000, Average Batch Loss: 0.6207
# Epoch 900/1000, Average Batch Loss: 0.3579
# Epoch 910/1000, Average Batch Loss: 0.4177
# Epoch 920/1000, Average Batch Loss: 0.7363
# Epoch 930/1000, Average Batch Loss: 0.8446
# Epoch 940/1000, Average Batch Loss: 0.8650
# Epoch 950/1000, Average Batch Loss: 0.8534
# Epoch 960/1000, Average Batch Loss: 0.7192
# Epoch 970/1000, Average Batch Loss: 0.4401
# Epoch 980/1000, Average Batch Loss: 0.4087
# Epoch 990/1000, Average Batch Loss: 0.3310
# Epoch 1000/1000, Average Batch Loss: 0.5434

# %%
# Plot the Learning Curve
plt.figure(figsize=(10, 5))

# Plot the saved list
plt.plot(loss_history, color='blue')
plt.title('RNN Training Loss Over Time for size 8')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (Loss)')
plt.grid(True)
plt.show()

# %%
# evaluate the model
print("Evaluating trained RNN in Closed-Loop Autoregressive for Size 8")
model.eval()

with torch.no_grad():
    continous_pred = []
    current_state = Y[0].to(device)

    # init hidden memory for all 20,000 steps
    h_k = torch.zeros(model.hidden_size, device=device)

    for k in range(len(U)):
        # get true input for this time step
        u_k = U[k].to(device)

        # combine current input with current force
        step_data = torch.cat((current_state, u_k))

        # forward pass this time step
        h_k = torch.relu(h_k @ model.W_hh + step_data @ model.W_uh + model.b_h)
        next_state_pred = h_k @ model.W_hx + model.b_x

        # save this prediction
        continous_pred.append(next_state_pred)

        # feedback loop
        current_state = next_state_pred

    Y_pred_norm = torch.stack(continous_pred)
    # Convert to numpy and un-normalize
    Y_pred = Y_pred_norm.cpu().numpy() * y_std + y_mean

# Plotting Results
plt.figure(figsize=(12, 8))

# Plot Rel Pos (z1)
plt.subplot(2, 1, 1)
plt.plot(y_vals[:, 0], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 0], 'r--', label='RNN Prediction')
plt.ylabel('Relative Position z1 (x1 - x2) (m)')
plt.legend()
plt.grid(True)

# Plot Absolute Position of M2 (z3)
plt.subplot(2, 1, 2)
plt.plot(y_vals[:, 2], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 2], 'g--', label='RNN Prediction')
plt.ylabel('Absolute Position of M2 (m)')
plt.xlabel('Time Steps')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Evaluating trained RNN in Closed-Loop Autoregressive for Size 8
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
