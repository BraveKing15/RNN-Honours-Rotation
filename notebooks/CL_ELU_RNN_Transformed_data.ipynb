# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %%
# Load the raw npz file
raw_data = np.load('../data/transformed_simulation_data.npz')
z_vals = raw_data['z_vals']
u_plot = raw_data['u_plot']

# z_vals contains [Rel Pos, Rel Vel, Abs Pos of M2, Abs Vel of M2]
columns = ['Input Force (u)', 'Rel Pos (z1)', 'Rel Vel (z2)', 'Abs Pos of M2 (z3)', 'Abs Vel of M2 (z4)']

# Create a DataFrame combining both raw arrays
# We use np.column_stack to attach the 1D u_plot alongside the 2D z_vals
df = pd.DataFrame(
    np.column_stack((u_plot, z_vals)),
    columns=columns
)

# Set the index name to represent Time Steps
df.index.name = 'Time Step'
display(df.head(10))
# Out:
#            Input Force (u)  Rel Pos (z1)  Rel Vel (z2)  Abs Pos of M2 (z3)  \
# Time Step
# 0                 0.993428      0.000000      0.000000        0.000000e+00
# 1                 0.993428      0.000196      0.039080        6.578013e-07
# 2                 0.993428      0.000777      0.076865        5.227087e-06
# 3                 0.993428      0.001730      0.113386        1.752287e-05
# 4                 0.993428      0.003041      0.148670        4.125689e-05
# 5                 0.993428      0.004699      0.182746        8.003968e-05
# 6                 0.993428      0.006692      0.215643        1.373827e-04
# 7                 0.993428      0.009008      0.247386        2.167003e-04
# 8                 0.993428      0.011636      0.278003        3.213117e-04
# 9                 0.993428      0.014564      0.307520        4.544431e-04
#
#            Abs Vel of M2 (z4)
# Time Step
# 0                    0.000000
# 1                    0.000197
# 2                    0.000781
# 3                    0.001740
# 4                    0.003066
# 5                    0.004749
# 6                    0.006777
# 7                    0.009142
# 8                    0.011834
# 9                    0.014844

# %%
# normalize the data 
z_mean, z_std = z_vals.mean(axis=0), z_vals.std(axis=0)
u_mean, u_std = u_plot.mean(), u_plot.std()

z_norm = (z_vals - z_mean) / (z_std + 1e-8)
u_norm = (u_plot - u_mean) / (u_std + 1e-8)

# convert to torch tensors
Z = torch.tensor(z_norm, dtype=torch.float32)
U = torch.tensor(u_norm, dtype=torch.float32).unsqueeze(1)

print(f"Data is normalized. Final shapes ready for model:")
print(f"Z Shape: {Z.shape} | U Shape: {U.shape}")
# Out:
# Data is normalized. Final shapes ready for model:
# Z Shape: torch.Size([20000, 4]) | U Shape: torch.Size([20000, 1])

# %%
# define the model
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        
        # Memory Update Weights
        self.W_hh = nn.Parameter(torch.randn(hidden_size, hidden_size) * 0.1)
        self.W_uh = nn.Parameter(torch.randn(input_size, hidden_size) * 0.1)
        self.b_h = nn.Parameter(torch.zeros(hidden_size))
        
        # State Prediction Weights
        self.W_hx = nn.Parameter(torch.randn(hidden_size, output_size) * 0.1)
        self.b_x = nn.Parameter(torch.zeros(output_size))
    
    def forward(self, combined_u_seq):
        # get sequence length
        seq_len = combined_u_seq.shape[0]

        # initialize hidden state
        h_k = torch.zeros(self.hidden_size, device=combined_u_seq.device)

        # initialize list to store predictions
        y_pred = []

        # loop through the sequence
        for k in range(seq_len):
            # contains [x1, v1, x2, v2, force]
            step_data = combined_u_seq[k]

            # update hidden state
            h_k = F.elu(h_k @ self.W_hh + step_data @ self.W_uh + self.b_h)

            # predict next state
            y_k = h_k @ self.W_hx + self.b_x

            # store prediction
            y_pred.append(y_k)

        # convert list to tensor
        y_pred = torch.stack(y_pred)

        return y_pred

# %% [markdown]
# # Training with `hidden_size=64` and `seq_len=100`. Also lowered learning rate to 0.0001 and applied gradient clipping

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Training on: {device}")

# train the model
model = RNN(input_size=5, hidden_size
# Epoch 570/1000, Average Batch Loss: 0.0557
# Epoch 580/1000, Average Batch Loss: 0.0321
# Epoch 590/1000, Average Batch Loss: 0.0395
# Epoch 600/1000, Average Batch Loss: 0.0338
# Epoch 610/1000, Average Batch Loss: 0.0355
# Epoch 620/1000, Average Batch Loss: 0.0374
# Epoch 630/1000, Average Batch Loss: 0.0411
# Epoch 640/1000, Average Batch Loss: 0.0369
# Epoch 650/1000, Average Batch Loss: 0.0322
# Epoch 660/1000, Average Batch Loss: 0.0431
# Epoch 670/1000, Average Batch Loss: 0.0251
# Epoch 680/1000, Average Batch Loss: 0.0261
# Epoch 690/1000, Average Batch Loss: 0.0184
# Epoch 700/1000, Average Batch Loss: 0.0261
# Epoch 710/1000, Average Batch Loss: 0.0230
# Epoch 720/1000, Average Batch Loss: 0.0266
# Epoch 730/1000, Average Batch Loss: 0.0237
# Epoch 740/1000, Average Batch Loss: 0.0287
# Epoch 750/1000, Average Batch Loss: 0.0238
# Epoch 760/1000, Average Batch Loss: 0.0166
# Epoch 770/1000, Average Batch Loss: 0.0191
# Epoch 780/1000, Average Batch Loss: 0.0192
# Epoch 790/1000, Average Batch Loss: 0.0168
# Epoch 800/1000, Average Batch Loss: 0.0229
# Epoch 810/1000, Average Batch Loss: 0.0197
# Epoch 820/1000, Average Batch Loss: 0.0237
# Epoch 830/1000, Average Batch Loss: 0.0159
# Epoch 840/1000, Average Batch Loss: 0.0211
# Epoch 850/1000, Average Batch Loss: 0.0181
# Epoch 860/1000, Average Batch Loss: 0.0183
# Epoch 870/1000, Average Batch Loss: 0.0198
# Epoch 880/1000, Average Batch Loss: 0.0166
# Epoch 890/1000, Average Batch Loss: 0.0154
# Epoch 900/1000, Average Batch Loss: 0.0120
# Epoch 910/1000, Average Batch Loss: 0.0175
# Epoch 920/1000, Average Batch Loss: 0.0131
# Epoch 930/1000, Average Batch Loss: 0.0094
# Epoch 940/1000, Average Batch Loss: 0.0188
# Epoch 950/1000, Average Batch Loss: 0.0107
# Epoch 960/1000, Average Batch Loss: 0.0131
# Epoch 970/1000, Average Batch Loss: 0.0187
# Epoch 980/1000, Average Batch Loss: 0.0179
# Epoch 990/1000, Average Batch Loss: 0.0099
# Epoch 1000/1000, Average Batch Loss: 0.0159

# %%
# Plot the Learning Curve
plt.figure(figsize=(10, 5))

# Plot the saved list
plt.plot(loss_history, color='blue')
plt.title('RNN Training Loss Over Time for size 64')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (Loss)')
plt.grid(True)
plt.show()

# %%
# evaluate the model
print("Evaluating trained RNN in Closed-Loop Autoregressive for Size 64")
model.eval()

with torch.no_grad():
    continous_pred = []
    current_state = Z[0].to(device)

    # init hidden memory for all 20,000 steps
    h_k = torch.zeros(model.hidden_size, device=device)

    for k in range(len(U)):
        # get true input for this time step
        u_k = U[k].to(device)

        # combine current input with current force
        step_data = torch.cat((current_state, u_k))

        # forward pass this time step
        h_k = F.elu(h_k @ model.W_hh + step_data @ model.W_uh + model.b_h)
        next_state_pred = h_k @ model.W_hx + model.b_x

        # save this prediction
        continous_pred.append(next_state_pred)

        # feedback loop
        current_state = next_state_pred

    Y_pred_norm = torch.stack(continous_pred)
    # Convert to numpy and un-normalize
    Y_pred = Y_pred_norm.cpu().numpy() * z_std + z_mean

# Plotting Results
plt.figure(figsize=(12, 8))

# Plot Rel Pos (z1)
plt.subplot(2, 1, 1)
plt.plot(z_vals[:, 0], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 0], 'r--', label='RNN Prediction')
plt.ylabel('Relative Position z1 (x1 - x2) (m)')
plt.legend()
plt.grid(True)

# Plot Absolute Position of M2 (z3)
plt.subplot(2, 1, 2)
plt.plot(z_vals[:, 2], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 2], 'g--', label='RNN Prediction')
plt.ylabel('Absolute Position of M2 (m)')
plt.xlabel('Time Steps')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Evaluating trained RNN in Closed-Loop Autoregressive for Size 64

# %% [markdown]
# # Try with same epochs (1000) but different hidden size (4)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Training on: {device}")

# train the model
model = RNN(input_size=5, hidden_size=4, output_size=4).to(device) # changed this to 5 (4 current states + 1 input force)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# training loop
n_epochs = 1000
seq_len = 100

loss_history = []

batch_size = 16

for epoch in range(n_epochs):
    # zero the gradients
    optimizer.zero_grad()
    
    batch_loss = 0

    for _ in range(batch_size):
        # Pick a random starting point in the sequence
        start_idx = np.random.randint(0, len(U) - seq_len - 1) # -1 cuz we need more space to get the traget one step in the future
        end_idx = start_idx + seq_len
        
        # Get current states and inputs
        U_curr = U[start_idx:end_idx].to(device)
        Z_curr = Z[start_idx:end_idx].to(device)
        
        # combine current state and input 
        combined_input = torch.cat((Z_curr, U_curr), dim=1)

        # NEW: get next states (target shifted by +1)
        Z_target = Z[start_idx + 1: end_idx + 1].to(device)

        # forward pass
        Z_pred_chunk = model(combined_input)
        
        # calculate loss
        loss = criterion(Z_pred_chunk, Z_target)
        loss = loss/batch_size
        
        # backpropagate and update
        loss.backward()
        batch_loss += (loss.item() * batch_size)
        
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
    optimizer.step()

    loss_history.append(loss.item())
    
    # print the loss every 10 epochs
    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch+1}/{n_epochs}, Average Batch Loss: {batch_loss / batch_size:.4f}")
# Out:
# Training on: cuda
# Epoch 10/1000, Average Batch Loss: 0.8085
# Epoch 20/1000, Average Batch Loss: 1.3223
# Epoch 30/1000, Average Batch Loss: 0.7541
# Epoch 40/1000, Average Batch Loss: 0.8618
# Epoch 50/1000, Average Batch Loss: 1.0792
# Epoch 60/1000, Average Batch Loss: 0.9219
# Epoch 70/1000, Average Batch Loss: 0.8017
# Epoch 80/1000, Average Batch Loss: 1.0271
# Epoch 90/1000, Average Batch Loss: 0.8838
# Epoch 100/1000, Average Batch Loss: 0.8219
# Epoch 110/1000, Average Batch Loss: 1.4961
# Epoch 120/1000, Average Batch Loss: 1.3186
# Epoch 130/1000, Average Batch Loss: 1.1405
# Epoch 140/1000, Average Batch Loss: 0.6744
# Epoch 150/1000, Average Batch Loss: 0.6391
# Epoch 750/1000, Average Batch Loss: 0.6065
# Epoch 760/1000, Average Batch Loss: 1.0749
# Epoch 770/1000, Average Batch Loss: 0.9059
# Epoch 780/1000, Average Batch Loss: 0.6191
# Epoch 790/1000, Average Batch Loss: 0.6937
# Epoch 800/1000, Average Batch Loss: 1.2486
# Epoch 810/1000, Average Batch Loss: 0.8149
# Epoch 820/1000, Average Batch Loss: 0.9639
# Epoch 830/1000, Average Batch Loss: 0.5534
# Epoch 840/1000, Average Batch Loss: 0.7850
# Epoch 850/1000, Average Batch Loss: 0.6286
# Epoch 860/1000, Average Batch Loss: 1.0025
# Epoch 870/1000, Average Batch Loss: 0.5993
# Epoch 880/1000, Average Batch Loss: 0.8372
# Epoch 890/1000, Average Batch Loss: 0.7973
# Epoch 900/1000, Average Batch Loss: 0.5717
# Epoch 910/1000, Average Batch Loss: 0.7324
# Epoch 920/1000, Average Batch Loss: 0.6604
# Epoch 930/1000, Average Batch Loss: 0.6552
# Epoch 940/1000, Average Batch Loss: 0.6554
# Epoch 950/1000, Average Batch Loss: 1.1503
# Epoch 960/1000, Average Batch Loss: 0.7570
# Epoch 970/1000, Average Batch Loss: 1.2125
# Epoch 980/1000, Average Batch Loss: 0.6558
# Epoch 990/1000, Average Batch Loss: 0.6053
# Epoch 1000/1000, Average Batch Loss: 0.8957

# %%
# Plot the Learning Curve
plt.figure(figsize=(10, 5))

# Plot the saved list
plt.plot(loss_history, color='blue')
plt.title('RNN Training Loss Over Time for size 4')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (Loss)')
plt.grid(True)
plt.show()

# %%
# evaluate the model
print("Evaluating trained RNN in Closed-Loop Autoregressive for Size 4")
model.eval()

with torch.no_grad():
    continous_pred = []
    current_state = Z[0].to(device)

    # init hidden memory for all 20,000 steps
    h_k = torch.zeros(model.hidden_size, device=device)

    for k in range(len(U)):
        # get true input for this time step
        u_k = U[k].to(device)

        # combine current input with current force
        step_data = torch.cat((current_state, u_k))

        # forward pass this time step
        h_k = F.elu(h_k @ model.W_hh + step_data @ model.W_uh + model.b_h)
        next_state_pred = h_k @ model.W_hx + model.b_x

        # save this prediction
        continous_pred.append(next_state_pred)

        # feedback loop
        current_state = next_state_pred

    Y_pred_norm = torch.stack(continous_pred)
    # Convert to numpy and un-normalize
    Y_pred = Y_pred_norm.cpu().numpy() * z_std + z_mean

# Plotting Results
plt.figure(figsize=(12, 8))

# Plot Rel Pos (z1)
plt.subplot(2, 1, 1)
plt.plot(z_vals[:, 0], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 0], 'r--', label='RNN Prediction')
plt.ylabel('Relative Position z1 (x1 - x2) (m)')
plt.legend()
plt.grid(True)

# Plot Absolute Position of M2 (z3)
plt.subplot(2, 1, 2)
plt.plot(z_vals[:, 2], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 2], 'g--', label='RNN Prediction')
plt.ylabel('Absolute Position of M2 (m)')
plt.xlabel('Time Steps')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Evaluating trained RNN in Closed-Loop Autoregressive for Size 4

# %% [markdown]
# # Try with hidden size (8) and epochs (1000)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Training on: {device}")

# train the model
model = RNN(input_size=5, hidden_size=8, output_size=4).to(device) # changed this to 5 (4 current states + 1 input force)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# training loop
n_epochs = 1000
seq_len = 100

loss_history = []

batch_size = 16

for epoch in range(n_epochs):
    # zero the gradients
    optimizer.zero_grad()
    
    batch_loss = 0

    for _ in range(batch_size):
        # Pick a random starting point in the sequence
        start_idx = np.random.randint(0, len(U) - seq_len - 1) # -1 cuz we need more space to get the traget one step in the future
        end_idx = start_idx + seq_len
        
        # Get current states and inputs
        U_curr = U[start_idx:end_idx].to(device)
        Z_curr = Z[start_idx:end_idx].to(device)
        
        # combine current state and input 
        combined_input = torch.cat((Z_curr, U_curr), dim=1)

        # NEW: get next states (target shifted by +1)
        Z_target = Z[start_idx + 1: end_idx + 1].to(device)

        # forward pass
        Z_pred_chunk = model(combined_input)
        
        # calculate loss
        loss = criterion(Z_pred_chunk, Z_target)
        loss = loss/batch_size
        
        # backpropagate and update
        loss.backward()
        batch_loss += (loss.item() * batch_size)
        
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
    optimizer.step()

    loss_history.append(loss.item())
    
    # print the loss every 10 epochs
    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch+1}/{n_epochs}, Average Batch Loss: {batch_loss / batch_size:.4f}")
# Out:
# Training on: cuda
# Epoch 10/1000, Average Batch Loss: 1.1986
# Epoch 20/1000, Average Batch Loss: 0.6717
# Epoch 30/1000, Average Batch Loss: 1.3358
# Epoch 40/1000, Average Batch Loss: 0.4339
# Epoch 50/1000, Average Batch Loss: 0.9918
# Epoch 60/1000, Average Batch Loss: 0.8514
# Epoch 70/1000, Average Batch Loss: 1.1261
# Epoch 80/1000, Average Batch Loss: 0.9142
# Epoch 90/1000, Average Batch Loss: 1.1825
# Epoch 100/1000, Average Batch Loss: 0.6874
# Epoch 110/1000, Average Batch Loss: 0.9104
# Epoch 120/1000, Average Batch Loss: 0.9360
# Epoch 130/1000, Average Batch Loss: 0.9986
# Epoch 140/1000, Average Batch Loss: 1.0542
# Epoch 150/1000, Average Batch Loss: 0.9754
# Epoch 160/1000, Average Batch Loss: 0.6904
# Epoch 170/1000, Average Batch Loss: 1.0244
# Epoch 180/1000, Average Batch Loss: 1.2753
# Epoch 190/1000, Average Batch Loss: 0.5009
# Epoch 200/1000, Average Batch Loss: 0.9350
# Epoch 210/1000, Average Batch Loss: 0.9386
# Epoch 220/1000, Average Batch Loss: 0.7510
# Epoch 230/1000, Average Batch Loss: 0.6144
# Epoch 240/1000, Average Batch Loss: 0.8406
# Epoch 250/1000, Average Batch Loss: 0.6691
# Epoch 260/1000, Average Batch Loss: 0.7069
# Epoch 270/1000, Average Batch Loss: 0.8887
# Epoch 280/1000, Average Batch Loss: 1.1389
# Epoch 290/1000, Average Batch Loss: 1.2515
# Epoch 300/1000, Average Batch Loss: 1.2635
# Epoch 310/1000, Average Batch Loss: 1.4640
# Epoch 320/1000, Average Batch Loss: 1.0116
# Epoch 330/1000, Average Batch Loss: 0.6063
# Epoch 340/1000, Average Batch Loss: 0.6464
# Epoch 350/1000, Average Batch Loss: 1.0415
# Epoch 360/1000, Average Batch Loss: 0.6128
# Epoch 370/1000, Average Batch Loss: 0.9696
# Epoch 380/1000, Average Batch Loss: 0.6508
# Epoch 390/1000, Average Batch Loss: 0.9494
# Epoch 400/1000, Average Batch Loss: 0.6976
# Epoch 410/1000, Average Batch Loss: 0.6849
# Epoch 420/1000, Average Batch Loss: 1.0324
# Epoch 430/1000, Average Batch Loss: 0.6201
# Epoch 440/1000, Average Batch Loss: 0.7217
# Epoch 450/1000, Average Batch Loss: 0.7934
# Epoch 460/1000, Average Batch Loss: 0.5839
# Epoch 470/1000, Average Batch Loss: 0.7686
# Epoch 480/1000, Average Batch Loss: 0.7264
# Epoch 490/1000, Average Batch Loss: 0.7334
# Epoch 500/1000, Average Batch Loss: 0.6994
# Epoch 510/1000, Average Batch Loss: 0.6455
# Epoch 520/1000, Average Batch Loss: 0.7815
# Epoch 530/1000, Average Batch Loss: 0.7163
# Epoch 540/1000, Average Batch Loss: 0.7856
# Epoch 550/1000, Average Batch Loss: 0.5849
# Epoch 560/1000, Average Batch Loss: 0.5961
# Epoch 570/1000, Average Batch Loss: 0.3968
# Epoch 580/1000, Average Batch Loss: 0.4075
# Epoch 590/1000, Average Batch Loss: 0.7185
# Epoch 600/1000, Average Batch Loss: 0.6436
# Epoch 610/1000, Average Batch Loss: 0.5681
# Epoch 620/1000, Average Batch Loss: 0.4213
# Epoch 630/1000, Average Batch Loss: 0.6697
# Epoch 640/1000, Average Batch Loss: 0.8864
# Epoch 650/1000, Average Batch Loss: 0.7412
# Epoch 660/1000, Average Batch Loss: 0.7931
# Epoch 670/1000, Average Batch Loss: 0.5035
# Epoch 680/1000, Average Batch Loss: 0.3892
# Epoch 690/1000, Average Batch Loss: 0.4232
# Epoch 700/1000, Average Batch Loss: 0.4642
# Epoch 710/1000, Average Batch Loss: 0.6448
# Epoch 720/1000, Average Batch Loss: 0.4920
# Epoch 730/1000, Average Batch Loss: 0.5489
# Epoch 740/1000, Average Batch Loss: 0.3644
# Epoch 750/1000, Average Batch Loss: 0.4194
# Epoch 760/1000, Average Batch Loss: 0.4838
# Epoch 770/1000, Average Batch Loss: 0.5373
# Epoch 780/1000, Average Batch Loss: 0.3927
# Epoch 790/1000, Average Batch Loss: 0.4951
# Epoch 800/1000, Average Batch Loss: 0.4324
# Epoch 810/1000, Average Batch Loss: 0.4339
# Epoch 820/1000, Average Batch Loss: 0.5119
# Epoch 830/1000, Average Batch Loss: 0.3373
# Epoch 840/1000, Average Batch Loss: 0.4592
# Epoch 850/1000, Average Batch Loss: 0.5099
# Epoch 860/1000, Average Batch Loss: 0.6777
# Epoch 870/1000, Average Batch Loss: 0.4369
# Epoch 880/1000, Average Batch Loss: 0.5361
# Epoch 890/1000, Average Batch Loss: 0.4681
# Epoch 900/1000, Average Batch Loss: 0.2588
# Epoch 910/1000, Average Batch Loss: 0.2970
# Epoch 920/1000, Average Batch Loss: 0.5438
# Epoch 930/1000, Average Batch Loss: 0.4520
# Epoch 940/1000, Average Batch Loss: 0.3637
# Epoch 950/1000, Average Batch Loss: 0.2917
# Epoch 960/1000, Average Batch Loss: 0.3213
# Epoch 970/1000, Average Batch Loss: 0.3375
# Epoch 980/1000, Average Batch Loss: 0.3968
# Epoch 990/1000, Average Batch Loss: 0.3428
# Epoch 1000/1000, Average Batch Loss: 0.2018

# %%
# Plot the Learning Curve
plt.figure(figsize=(10, 5))

# Plot the saved list
plt.plot(loss_history, color='blue')
plt.title('RNN Training Loss Over Time for size 8')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (Loss)')
plt.grid(True)
plt.show()

# %%
# evaluate the model
print("Evaluating trained RNN in Closed-Loop Autoregressive for Size 8")
model.eval()

with torch.no_grad():
    continous_pred = []
    current_state = Z[0].to(device)

    # init hidden memory for all 20,000 steps
    h_k = torch.zeros(model.hidden_size, device=device)

    for k in range(len(U)):
        # get true input for this time step
        u_k = U[k].to(device)

        # combine current input with current force
        step_data = torch.cat((current_state, u_k))

        # forward pass this time step
        h_k = F.elu(h_k @ model.W_hh + step_data @ model.W_uh + model.b_h)
        next_state_pred = h_k @ model.W_hx + model.b_x

        # save this prediction
        continous_pred.append(next_state_pred)

        # feedback loop
        current_state = next_state_pred

    Y_pred_norm = torch.stack(continous_pred)
    # Convert to numpy and un-normalize
    Y_pred = Y_pred_norm.cpu().numpy() * z_std + z_mean

# Plotting Results
plt.figure(figsize=(12, 8))

# Plot Rel Pos (z1)
plt.subplot(2, 1, 1)
plt.plot(z_vals[:, 0], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 0], 'r--', label='RNN Prediction')
plt.ylabel('Relative Position z1 (x1 - x2) (m)')
plt.legend()
plt.grid(True)

# Plot Absolute Position of M2 (z3)
plt.subplot(2, 1, 2)
plt.plot(z_vals[:, 2], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 2], 'g--', label='RNN Prediction')
plt.ylabel('Absolute Position of M2 (m)')
plt.xlabel('Time Steps')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Evaluating trained RNN in Closed-Loop Autoregressive for Size 8
