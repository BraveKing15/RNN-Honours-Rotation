# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
# Load the raw npz file
raw_data = np.load('../data/transformed_simulation_data.npz')
z_vals = raw_data['z_vals']
u_plot = raw_data['u_plot']

# z_vals contains [Rel Pos, Rel Vel, Abs Pos of M2, Abs Vel of M2]
columns = ['Input Force (u)', 'Rel Pos (z1)', 'Rel Vel (z2)', 'Abs Pos of M2 (z3)', 'Abs Vel of M2 (z4)']

# Create a DataFrame combining both raw arrays
# We use np.column_stack to attach the 1D u_plot alongside the 2D z_vals
df = pd.DataFrame(
    np.column_stack((u_plot, z_vals)),
    columns=columns
)

# Set the index name to represent Time Steps
df.index.name = 'Time Step'
display(df.head(10))
# Out:
#            Input Force (u)  Rel Pos (z1)  Rel Vel (z2)  Abs Pos of M2 (z3)  \
# Time Step
# 0                 0.993428      0.000000      0.000000        0.000000e+00
# 1                 0.993428      0.000196      0.039080        6.578013e-07
# 2                 0.993428      0.000777      0.076865        5.227087e-06
# 3                 0.993428      0.001730      0.113386        1.752287e-05
# 4                 0.993428      0.003041      0.148670        4.125689e-05
# 5                 0.993428      0.004699      0.182746        8.003968e-05
# 6                 0.993428      0.006692      0.215643        1.373827e-04
# 7                 0.993428      0.009008      0.247386        2.167003e-04
# 8                 0.993428      0.011636      0.278003        3.213117e-04
# 9                 0.993428      0.014564      0.307520        4.544431e-04
#
#            Abs Vel of M2 (z4)
# Time Step
# 0                    0.000000
# 1                    0.000197
# 2                    0.000781
# 3                    0.001740
# 4                    0.003066
# 5                    0.004749
# 6                    0.006777
# 7                    0.009142
# 8                    0.011834
# 9                    0.014844

# %%
# normalize the data 
z_mean, z_std = z_vals.mean(axis=0), z_vals.std(axis=0)
u_mean, u_std = u_plot.mean(), u_plot.std()

z_norm = (z_vals - z_mean) / (z_std + 1e-8)
u_norm = (u_plot - u_mean) / (u_std + 1e-8)

# convert to torch tensors
Z = torch.tensor(z_norm, dtype=torch.float32)
U = torch.tensor(u_norm, dtype=torch.float32).unsqueeze(1)

print(f"Data is normalized. Final shapes ready for model:")
print(f"Z Shape: {Z.shape} | U Shape: {U.shape}")
# Out:
# Data is normalized. Final shapes ready for model:
# Z Shape: torch.Size([20000, 4]) | U Shape: torch.Size([20000, 1])

# %%
# define the model
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        
        # Memory Update Weights
        self.W_hh = nn.Parameter(torch.randn(hidden_size, hidden_size) * 0.1)
        self.W_uh = nn.Parameter(torch.randn(input_size, hidden_size) * 0.1)
        self.b_h = nn.Parameter(torch.zeros(hidden_size))
        
        # State Prediction Weights
        self.W_hx = nn.Parameter(torch.randn(hidden_size, output_size) * 0.1)
        self.b_x = nn.Parameter(torch.zeros(output_size))
    
    def forward(self, combined_u_seq):
        # get sequence length
        seq_len = combined_u_seq.shape[0]

        # initialize hidden state
        h_k = torch.zeros(self.hidden_size, device=combined_u_seq.device)

        # initialize list to store predictions
        y_pred = []

        # loop through the sequence
        for k in range(seq_len):
            # contains [x1, v1, x2, v2, force]
            step_data = combined_u_seq[k]

            # update hidden state
            h_k = torch.tanh(h_k @ self.W_hh + step_data @ self.W_uh + self.b_h)

            # predict next state
            y_k = h_k @ self.W_hx + self.b_x

            # store prediction
            y_pred.append(y_k)

        # convert list to tensor
        y_pred = torch.stack(y_pred)

        return y_pred

# %% [markdown]
# # Training with `hidden_size=64` and `seq_len=100`. Also lowered learning rate to 0.0001 and applied gradient clipping

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Training on: {device}")

# train the model
model = RNN(input_size=5, hidden_size=64, output_size=4).to(device) # changed this to 5 (4 current states + 1 input force)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# training loop
n_epochs = 1000
seq_len = 100

loss_history = []

batch_size = 16

for epoch in range(n_epochs):
    # zero the gradients
    optimizer.zero_grad()
    
    batch_loss = 0

    for _ in range(batch_size):
        # Pick a random starting point in the sequence
        start_idx = np.random.randint(0, len(U) - seq_len - 1) # -1 cuz we need more space to get the traget one step in the future
        end_idx = start_idx + seq_len
        
        # Get current states and inputs
        U_curr = U[start_idx:end_idx].to(device)
        Z_curr = Z[start_idx:end_idx].to(device)
        
        # combine current state and input 
        combined_input = torch.cat((Z_curr, U_curr), dim=1)

        # NEW: get next states (target shifted by +1)
        Z_target = Z[start_idx + 1: end_idx + 1].to(device)

        # forward pass
        Z_pred_chunk = model(combined_input)
        
        # calculate loss
        loss = criterion(Z_pred_chunk, Z_target)
        loss = loss/batch_size
        
        # backpropagate and update
        loss.backward()
        batch_loss += (loss.item() * batch_size)
        
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
    optimizer.step()

    loss_history.append(loss.item())
    
    # print the loss every 10 epochs
    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch+1}/{n_epochs}, Average Batch Loss: {batch_loss / batch_size:.4f}")
# Out:
# Training on: cuda
# Epoch 10/1000, Average Batch Loss: 0.8775
# Epoch 20/1000, Average Batch Loss: 1.3939
# Epoch 30/1000, Average Batch Loss: 0.8431
# Epoch 40/1000, Average Batch Loss: 1.0241
# Epoch 50/1000, Average Batch Loss: 1.1515
# Epoch 60/1000, Average Batch Loss: 0.8473
# Epoch 70/1000, Average Batch Loss: 0.3426
# Epoch 80/1000, Average Batch Loss: 0.5185
# Epoch 90/1000, Average Batch Loss: 0.2057
# Epoch 100/1000, Average Batch Loss: 0.5057
# Epoch 110/1000, Average Batch Loss: 0.3861
# Epoch 120/1000, Average Batch Loss: 0.2801
# Epoch 130/1000, Average Batch Loss: 0.2613
# Epoch 140/1000, Average Batch Loss: 0.1217
# Epoch 150/1000, Average Batch Loss: 0.2102
# Epoch 160/1000, Average Batch Loss: 0.0862
# Epoch 170/1000, Average Batch Loss: 0.1490
# Epoch 180/1000, Average Batch Loss: 0.1366
# Epoch 190/1000, Average Batch Loss: 0.1731
# Epoch 200/1000, Average Batch Loss: 0.0801
# Epoch 210/1000, Average Batch Loss: 0.1392
# Epoch 220/1000, Average Batch Loss: 0.1146
# Epoch 230/1000, Average Batch Loss: 0.1625
# Epoch 240/1000, Average Batch Loss: 0.2412
# Epoch 250/1000, Average Batch Loss: 0.0437
# Epoch 260/1000, Average Batch Loss: 0.0695
# Epoch 270/1000, Average Batch Loss: 0.0733
# Epoch 280/1000, Average Batch Loss: 0.1685
# Epoch 290/1000, Average Batch Loss: 0.0533
# Epoch 300/1000, Average Batch Loss: 0.0906
# Epoch 310/1000, Average Batch Loss: 0.0549
# Epoch 320/1000, Average Batch Loss: 0.0640
# Epoch 330/1000, Average Batch Loss: 0.0751
# Epoch 340/1000, Average Batch Loss: 0.0513
# Epoch 350/1000, Average Batch Loss: 0.0973
# Epoch 360/1000, Average Batch Loss: 0.0735
# Epoch 370/1000, Average Batch Loss: 0.0581
# Epoch 380/1000, Average Batch Loss: 0.0555
# Epoch 390/1000, Average Batch Loss: 0.0340
# Epoch 400/1000, Average Batch Loss: 0.0650
# Epoch 410/1000, Average Batch Loss: 0.0353
# Epoch 420/1000, Average Batch Loss: 0.0271
# Epoch 430/1000, Average Batch Loss: 0.0822
# Epoch 440/1000, Average Batch Loss: 0.0650
# Epoch 450/1000, Average Batch Loss: 0.0234
# Epoch 460/1000, Average Batch Loss: 0.0331
# Epoch 470/1000, Average Batch Loss: 0.0205
# Epoch 480/1000, Average Batch Loss: 0.0277
# Epoch 490/1000, Average Batch Loss: 0.0570
# Epoch 500/1000, Average Batch Loss: 0.0279
# Epoch 510/1000, Average Batch Loss: 0.0420
# Epoch 520/1000, Average Batch Loss: 0.0394
# Epoch 530/1000, Average Batch Loss: 0.0293
# Epoch 540/1000, Average Batch Loss: 0.0187
# Epoch 550/1000, Average Batch Loss: 0.0194
# Epoch 560/1000, Average Batch Loss: 0.0147
# Epoch 570/1000, Average Batch Loss: 0.0215
# Epoch 580/1000, Average Batch Loss: 0.0159
# Epoch 590/1000, Average Batch Loss: 0.0579
# Epoch 600/1000, Average Batch Loss: 0.0550
# Epoch 610/1000, Average Batch Loss: 0.0227
# Epoch 620/1000, Average Batch Loss: 0.0333
# Epoch 630/1000, Average Batch Loss: 0.0288
# Epoch 640/1000, Average Batch Loss: 0.0388
# Epoch 650/1000, Average Batch Loss: 0.0179
# Epoch 660/1000, Average Batch Loss: 0.0311
# Epoch 670/1000, Average Batch Loss: 0.0203
# Epoch 680/1000, Average Batch Loss: 0.0309
# Epoch 690/1000, Average Batch Loss: 0.0378
# Epoch 700/1000, Average Batch Loss: 0.0208
# Epoch 710/1000, Average Batch Loss: 0.0164
# Epoch 720/1000, Average Batch Loss: 0.0143
# Epoch 730/1000, Average Batch Loss: 0.0367
# Epoch 740/1000, Average Batch Loss: 0.0295
# Epoch 750/1000, Average Batch Loss: 0.0296
# Epoch 760/1000, Average Batch Loss: 0.0211
# Epoch 770/1000, Average Batch Loss: 0.0286
# Epoch 780/1000, Average Batch Loss: 0.0167
# Epoch 790/1000, Average Batch Loss: 0.0238
# Epoch 800/1000, Average Batch Loss: 0.0146
# Epoch 810/1000, Average Batch Loss: 0.0259
# Epoch 820/1000, Average Batch Loss: 0.0126
# Epoch 830/1000, Average Batch Loss: 0.0162
# Epoch 840/1000, Average Batch Loss: 0.0153
# Epoch 850/1000, Average Batch Loss: 0.0194
# Epoch 860/1000, Average Batch Loss: 0.0099
# Epoch 870/1000, Average Batch Loss: 0.0144
# Epoch 880/1000, Average Batch Loss: 0.0213
# Epoch 890/1000, Average Batch Loss: 0.0137
# Epoch 900/1000, Average Batch Loss: 0.0091
# Epoch 910/1000, Average Batch Loss: 0.0259
# Epoch 920/1000, Average Batch Loss: 0.0291
# Epoch 930/1000, Average Batch Loss: 0.0317
# Epoch 940/1000, Average Batch Loss: 0.0132
# Epoch 950/1000, Average Batch Loss: 0.0191
# Epoch 960/1000, Average Batch Loss: 0.0189
# Epoch 970/1000, Average Batch Loss: 0.0096
# Epoch 980/1000, Average Batch Loss: 0.0203
# Epoch 990/1000, Average Batch Loss: 0.0158
# Epoch 1000/1000, Average Batch Loss: 0.0111

# %%
# Plot the Learning Curve
plt.figure(figsize=(10, 5))

# Plot the saved list
plt.plot(loss_history, color='blue')
plt.title('RNN Training Loss Over Time for size 64')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (Loss)')
plt.grid(True)
plt.show()

# %%
# evaluate the model
print("Evaluating trained RNN in Closed-Loop Autoregressive for Size 64")
model.eval()

with torch.no_grad():
    continous_pred = []
    current_state = Z[0].to(device)

    # init hidden memory for all 20,000 steps
    h_k = torch.zeros(model.hidden_size, device=device)

    for k in range(len(U)):
        # get true input for this time step
        u_k = U[k].to(device)

        # combine current input with current force
        step_data = torch.cat((current_state, u_k))

        # forward pass this time step
        h_k = torch.tanh(h_k @ model.W_hh + step_data @ model.W_uh + model.b_h)
        next_state_pred = h_k @ model.W_hx + model.b_x

        # save this prediction
        continous_pred.append(next_state_pred)

        # feedback loop
        current_state = next_state_pred

    Y_pred_norm = torch.stack(continous_pred)
    # Convert to numpy and un-normalize
    Y_pred = Y_pred_norm.cpu().numpy() * z_std + z_mean

# Plotting Results
plt.figure(figsize=(12, 8))

# Plot Rel Pos (z1)
plt.subplot(2, 1, 1)
plt.plot(z_vals[:, 0], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 0], 'r--', label='RNN Prediction')
plt.ylabel('Relative Position z1 (x1 - x2) (m)')
plt.legend()
plt.grid(True)

# Plot Absolute Position of M2 (z3)
plt.subplot(2, 1, 2)
plt.plot(z_vals[:, 2], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 2], 'g--', label='RNN Prediction')
plt.ylabel('Absolute Position of M2 (m)')
plt.xlabel('Time Steps')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Evaluating trained RNN in Closed-Loop Autoregressive for Size 64

# %% [markdown]
# # Try with same epochs (1000) but different hidden size (4)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Training on: {device}")

# train the model
model = RNN(input_size=5, hidden_size=4, output_size=4).to(device) # changed this to 5 (4 current states + 1 input force)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# training loop
n_epochs = 1000
seq_len = 100

loss_history = []

batch_size = 16

for epoch in range(n_epochs):
    # zero the gradients
    optimizer.zero_grad()
    
    batch_loss = 0

    for _ in range(batch_size):
        # Pick a random starting point in the sequence
        start_idx = np.random.randint(0, len(U) - seq_len - 1) # -1 cuz we need more space to get the traget one step in the future
        end_idx = start_idx + seq_len
        
        # Get current states and inputs
        U_curr = U[start_idx:end_idx].to(device)
        Z_curr = Z[start_idx:end_idx].to(device)
        
        # combine current state and input 
        combined_input = torch.cat((Z_curr, U_curr), dim=1)

        # NEW: get next states (target shifted by +1)
        Z_target = Z[start_idx + 1: end_idx + 1].to(device)

        # forward pass
        Z_pred_chunk = model(combined_input)
        
        # calculate loss
        loss = criterion(Z_pred_chunk, Z_target)
        loss = loss/batch_size
        
        # backpropagate and update
        loss.backward()
        batch_loss += (loss.item() * batch_size)
        
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
    optimizer.step()

    loss_history.append(loss.item())
    
    # print the loss every 10 epochs
    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch+1}/{n_epochs}, Average Batch Loss: {batch_loss / batch_size:.4f}")
# Out:
# Training on: cuda
# Epoch 10/1000, Average Batch Loss: 1.4705
# Epoch 20/1000, Average Batch Loss: 1.0757
# Epoch 30/1000, Average Batch Loss: 0.8510
# Epoch 40/1000, Average Batch Loss: 0.8285
# Epoch 50/1000, Average Batch Loss: 1.0190
# Epoch 60/1000, Average Batch Loss: 1.3105
# Epoch 70/1000, Average Batch Loss: 0.7269
# Epoch 80/1000, Average Batch Loss: 0.6229
# Epoch 90/1000, Average Batch Loss: 0.7328
# Epoch 100/1000, Average Batch Loss: 1.3979
# Epoch 110/1000, Average Batch Loss: 0.7477
# Epoch 120/1000, Average Batch Loss: 0.6594
# Epoch 130/1000, Average Batch Loss: 0.8780
# Epoch 140/1000, Average Batch Loss: 0.8726
# Epoch 150/1000, Average Batch Loss: 1.5160
# Epoch 160/1000, Average Batch Loss: 0.9485
# Epoch 170/1000, Average Batch Loss: 1.3264
# Epoch 180/1000, Average Batch Loss: 0.9646
# Epoch 190/1000, Average Batch Loss: 0.8738
# Epoch 200/1000, Average Batch Loss: 0.9485
# Epoch 210/1000, Average Batch Loss: 0.7957
# Epoch 220/1000, Average Batch Loss: 1.3254
# Epoch 230/1000, Average Batch Loss: 1.0639
# Epoch 240/1000, Average Batch Loss: 0.7296
# Epoch 250/1000, Average Batch Loss: 1.1969
# Epoch 260/1000, Average Batch Loss: 1.2861
# Epoch 270/1000, Average Batch Loss: 0.9687
# Epoch 280/1000, Average Batch Loss: 0.5253
# Epoch 290/1000, Average Batch Loss: 1.4119
# Epoch 300/1000, Average Batch Loss: 0.4475
# Epoch 310/1000, Average Batch Loss: 0.8432
# Epoch 320/1000, Average Batch Loss: 0.9987
# Epoch 330/1000, Average Batch Loss: 0.8348
# Epoch 340/1000, Average Batch Loss: 0.7240
# Epoch 350/1000, Average Batch Loss: 0.5338
# Epoch 360/1000, Average Batch Loss: 1.0057
# Epoch 370/1000, Average Batch Loss: 0.8435
# Epoch 380/1000, Average Batch Loss: 0.7539
# Epoch 390/1000, Average Batch Loss: 0.5358
# Epoch 400/1000, Average Batch Loss: 0.7249
# Epoch 410/1000, Average Batch Loss: 0.8544
# Epoch 420/1000, Average Batch Loss: 0.9063
# Epoch 430/1000, Average Batch Loss: 1.2421
# Epoch 440/1000, Average Batch Loss: 0.9486
# Epoch 450/1000, Average Batch Loss: 0.8399
# Epoch 460/1000, Average Batch Loss: 1.1042
# Epoch 470/1000, Average Batch Loss: 0.8999
# Epoch 480/1000, Average Batch Loss: 0.5766
# Epoch 490/1000, Average Batch Loss: 0.7499
# Epoch 500/1000, Average Batch Loss: 0.8990
# Epoch 510/1000, Average Batch Loss: 0.9850
# Epoch 520/1000, Average Batch Loss: 1.1257
# Epoch 530/1000, Average Batch Loss: 1.0399
# Epoch 540/1000, Average Batch Loss: 1.1237
# Epoch 550/1000, Average Batch Loss: 0.9640
# Epoch 560/1000, Average Batch Loss: 0.9499
# Epoch 570/1000, Average Batch Loss: 0.8902
# Epoch 580/1000, Average Batch Loss: 0.6643
# Epoch 590/1000, Average Batch Loss: 0.7628
# Epoch 600/1000, Average Batch Loss: 0.8145
# Epoch 610/1000, Average Batch Loss: 0.7310
# Epoch 620/1000, Average Batch Loss: 0.6013
# Epoch 630/1000, Average Batch Loss: 1.0587
# Epoch 640/1000, Average Batch Loss: 0.8367
# Epoch 650/1000, Average Batch Loss: 0.7932
# Epoch 660/1000, Average Batch Loss: 0.7986
# Epoch 670/1000, Average Batch Loss: 0.6495
# Epoch 680/1000, Average Batch Loss: 0.6972
# Epoch 690/1000, Average Batch Loss: 0.8945
# Epoch 700/1000, Average Batch Loss: 1.0587
# Epoch 710/1000, Average Batch Loss: 1.4098
# Epoch 720/1000, Average Batch Loss: 1.0448
# Epoch 730/1000, Average Batch Loss: 1.1942
# Epoch 740/1000, Average Batch Loss: 0.5406
# Epoch 750/1000, Average Batch Loss: 0.7333
# Epoch 760/1000, Average Batch Loss: 0.9646
# Epoch 770/1000, Average Batch Loss: 0.8307
# Epoch 780/1000, Average Batch Loss: 0.8476
# Epoch 790/1000, Average Batch Loss: 0.8786
# Epoch 800/1000, Average Batch Loss: 1.0053
# Epoch 810/1000, Average Batch Loss: 1.0551
# Epoch 820/1000, Average Batch Loss: 0.6371
# Epoch 830/1000, Average Batch Loss: 0.7170
# Epoch 840/1000, Average Batch Loss: 1.0256
# Epoch 850/1000, Average Batch Loss: 1.0075
# Epoch 860/1000, Average Batch Loss: 1.1149
# Epoch 870/1000, Average Batch Loss: 0.9355
# Epoch 880/1000, Average Batch Loss: 0.6480
# Epoch 890/1000, Average Batch Loss: 0.4874
# Epoch 900/1000, Average Batch Loss: 0.6999
# Epoch 910/1000, Average Batch Loss: 0.4269
# Epoch 920/1000, Average Batch Loss: 1.1459
# Epoch 930/1000, Average Batch Loss: 1.0788
# Epoch 940/1000, Average Batch Loss: 0.6555
# Epoch 950/1000, Average Batch Loss: 0.6023
# Epoch 960/1000, Average Batch Loss: 1.1092
# Epoch 970/1000, Average Batch Loss: 0.6163
# Epoch 980/1000, Average Batch Loss: 0.6955
# Epoch 990/1000, Average Batch Loss: 0.6244
# Epoch 1000/1000, Average Batch Loss: 0.9306

# %%
# Plot the Learning Curve
plt.figure(figsize=(10, 5))

# Plot the saved list
plt.plot(loss_history, color='blue')
plt.title('RNN Training Loss Over Time for size 4')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (Loss)')
plt.grid(True)
plt.show()

# %%
# evaluate the model
print("Evaluating trained RNN in Closed-Loop Autoregressive for Size 4")
model.eval()

with torch.no_grad():
    continous_pred = []
    current_state = Z[0].to(device)

    # init hidden memory for all 20,000 steps
    h_k = torch.zeros(model.hidden_size, device=device)

    for k in range(len(U)):
        # get true input for this time step
        u_k = U[k].to(device)

        # combine current input with current force
        step_data = torch.cat((current_state, u_k))

        # forward pass this time step
        h_k = torch.tanh(h_k @ model.W_hh + step_data @ model.W_uh + model.b_h)
        next_state_pred = h_k @ model.W_hx + model.b_x

        # save this prediction
        continous_pred.append(next_state_pred)

        # feedback loop
        current_state = next_state_pred

    Y_pred_norm = torch.stack(continous_pred)
    # Convert to numpy and un-normalize
    Y_pred = Y_pred_norm.cpu().numpy() * z_std + z_mean

# Plotting Results
plt.figure(figsize=(12, 8))

# Plot Rel Pos (z1)
plt.subplot(2, 1, 1)
plt.plot(z_vals[:, 0], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 0], 'r--', label='RNN Prediction')
plt.ylabel('Relative Position z1 (x1 - x2) (m)')
plt.legend()
plt.grid(True)

# Plot Absolute Position of M2 (z3)
plt.subplot(2, 1, 2)
plt.plot(z_vals[:, 2], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 2], 'g--', label='RNN Prediction')
plt.ylabel('Absolute Position of M2 (m)')
plt.xlabel('Time Steps')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Evaluating trained RNN in Closed-Loop Autoregressive for Size 4

# %% [markdown]
# # Try with hidden size (8) and epochs (1000)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Training on: {device}")

# train the model
model = RNN(input_size=5, hidden_size=8, output_size=4).to(device) # changed this to 5 (4 current states + 1 input force)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# training loop
n_epochs = 1000
seq_len = 100

loss_history = []

batch_size = 16

for epoch in range(n_epochs):
    # zero the gradients
    optimizer.zero_grad()
    
    batch_loss = 0

    for _ in range(batch_size):
        # Pick a random starting point in the sequence
        start_idx = np.random.randint(0, len(U) - seq_len - 1) # -1 cuz we need more space to get the traget one step in the future
        end_idx = start_idx + seq_len
        
        # Get current states and inputs
        U_curr = U[start_idx:end_idx].to(device)
        Z_curr = Z[start_idx:end_idx].to(device)
        
        # combine current state and input 
        combined_input = torch.cat((Z_curr, U_curr), dim=1)

        # NEW: get next states (target shifted by +1)
        Z_target = Z[start_idx + 1: end_idx + 1].to(device)

        # forward pass
        Z_pred_chunk = model(combined_input)
        
        # calculate loss
        loss = criterion(Z_pred_chunk, Z_target)
        loss = loss/batch_size
        
        # backpropagate and update
        loss.backward()
        batch_loss += (loss.item() * batch_size)
        
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
    optimizer.step()

    loss_history.append(loss.item())
    
    # print the loss every 10 epochs
    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch+1}/{n_epochs}, Average Batch Loss: {batch_loss / batch_size:.4f}")
# Out:
# Training on: cuda
# Epoch 10/1000, Average Batch Loss: 1.0453
# Epoch 20/1000, Average Batch Loss: 1.0211
# Epoch 30/1000, Average Batch Loss: 0.8170
# Epoch 40/1000, Average Batch Loss: 1.6740
# Epoch 50/1000, Average Batch Loss: 1.4620
# Epoch 60/1000, Average Batch Loss: 0.9644
# Epoch 70/1000, Average Batch Loss: 1.1373
# Epoch 80/1000, Average Batch Loss: 0.9083
# Epoch 90/1000, Average Batch Loss: 0.6839
# Epoch 100/1000, Average Batch Loss: 1.0395
# Epoch 110/1000, Average Batch Loss: 0.7000
# Epoch 120/1000, Average Batch Loss: 0.6755
# Epoch 130/1000, Average Batch Loss: 1.1859
# Epoch 140/1000, Average Batch Loss: 1.0170
# Epoch 150/1000, Average Batch Loss: 0.7219
# Epoch 160/1000, Average Batch Loss: 1.1570
# Epoch 170/1000, Average Batch Loss: 0.8420
# Epoch 180/1000, Average Batch Loss: 0.9668
# Epoch 190/1000, Average Batch Loss: 0.8662
# Epoch 200/1000, Average Batch Loss: 0.8393
# Epoch 210/1000, Average Batch Loss: 0.9183
# Epoch 220/1000, Average Batch Loss: 0.6311
# Epoch 230/1000, Average Batch Loss: 0.9881
# Epoch 240/1000, Average Batch Loss: 1.1410
# Epoch 250/1000, Average Batch Loss: 0.7380
# Epoch 260/1000, Average Batch Loss: 1.3738
# Epoch 270/1000, Average Batch Loss: 0.5475
# Epoch 280/1000, Average Batch Loss: 0.7590
# Epoch 290/1000, Average Batch Loss: 0.6642
# Epoch 300/1000, Average Batch Loss: 1.1087
# Epoch 310/1000, Average Batch Loss: 0.8390
# Epoch 320/1000, Average Batch Loss: 0.9105
# Epoch 330/1000, Average Batch Loss: 0.4935
# Epoch 340/1000, Average Batch Loss: 0.8586
# Epoch 350/1000, Average Batch Loss: 0.8464
# Epoch 360/1000, Average Batch Loss: 0.7852
# Epoch 370/1000, Average Batch Loss: 0.7705
# Epoch 380/1000, Average Batch Loss: 1.3984
# Epoch 390/1000, Average Batch Loss: 0.5875
# Epoch 400/1000, Average Batch Loss: 0.6791
# Epoch 410/1000, Average Batch Loss: 0.4896
# Epoch 420/1000, Average Batch Loss: 1.1158
# Epoch 430/1000, Average Batch Loss: 0.5665
# Epoch 440/1000, Average Batch Loss: 0.8615
# Epoch 450/1000, Average Batch Loss: 0.6465
# Epoch 460/1000, Average Batch Loss: 0.9303
# Epoch 470/1000, Average Batch Loss: 0.4342
# Epoch 480/1000, Average Batch Loss: 0.9304
# Epoch 490/1000, Average Batch Loss: 0.6828
# Epoch 500/1000, Average Batch Loss: 0.9583
# Epoch 510/1000, Average Batch Loss: 0.8665
# Epoch 520/1000, Average Batch Loss: 0.6634
# Epoch 530/1000, Average Batch Loss: 0.8311
# Epoch 540/1000, Average Batch Loss: 0.7533
# Epoch 550/1000, Average Batch Loss: 0.9363
# Epoch 560/1000, Average Batch Loss: 0.9962
# Epoch 570/1000, Average Batch Loss: 0.8816
# Epoch 580/1000, Average Batch Loss: 1.1283
# Epoch 590/1000, Average Batch Loss: 0.4606
# Epoch 600/1000, Average Batch Loss: 0.5926
# Epoch 610/1000, Average Batch Loss: 0.3264
# Epoch 620/1000, Average Batch Loss: 0.4960
# Epoch 630/1000, Average Batch Loss: 0.8561
# Epoch 640/1000, Average Batch Loss: 0.5819
# Epoch 650/1000, Average Batch Loss: 0.4339
# Epoch 660/1000, Average Batch Loss: 0.5540
# Epoch 670/1000, Average Batch Loss: 0.7886
# Epoch 680/1000, Average Batch Loss: 0.5555
# Epoch 690/1000, Average Batch Loss: 0.4624
# Epoch 700/1000, Average Batch Loss: 0.7092
# Epoch 710/1000, Average Batch Loss: 0.7425
# Epoch 720/1000, Average Batch Loss: 0.7577
# Epoch 730/1000, Average Batch Loss: 0.7153
# Epoch 740/1000, Average Batch Loss: 1.3018
# Epoch 750/1000, Average Batch Loss: 0.8311
# Epoch 760/1000, Average Batch Loss: 0.4609
# Epoch 770/1000, Average Batch Loss: 0.3382
# Epoch 780/1000, Average Batch Loss: 0.6985
# Epoch 790/1000, Average Batch Loss: 0.9964
# Epoch 800/1000, Average Batch Loss: 0.5505
# Epoch 810/1000, Average Batch Loss: 0.8524
# Epoch 820/1000, Average Batch Loss: 0.5731
# Epoch 830/1000, Average Batch Loss: 0.4459
# Epoch 840/1000, Average Batch Loss: 0.4012
# Epoch 850/1000, Average Batch Loss: 0.5225
# Epoch 860/1000, Average Batch Loss: 0.5042
# Epoch 870/1000, Average Batch Loss: 0.6535
# Epoch 880/1000, Average Batch Loss: 0.6487
# Epoch 890/1000, Average Batch Loss: 0.6358
# Epoch 900/1000, Average Batch Loss: 0.7006
# Epoch 910/1000, Average Batch Loss: 0.5597
# Epoch 920/1000, Average Batch Loss: 0.6510
# Epoch 930/1000, Average Batch Loss: 0.4268
# Epoch 940/1000, Average Batch Loss: 0.7913
# Epoch 950/1000, Average Batch Loss: 0.4715
# Epoch 960/1000, Average Batch Loss: 0.4875
# Epoch 970/1000, Average Batch Loss: 0.7615
# Epoch 980/1000, Average Batch Loss: 0.5130
# Epoch 990/1000, Average Batch Loss: 0.3460
# Epoch 1000/1000, Average Batch Loss: 0.4195

# %%
# Plot the Learning Curve
plt.figure(figsize=(10, 5))

# Plot the saved list
plt.plot(loss_history, color='blue')
plt.title('RNN Training Loss Over Time for size 8')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (Loss)')
plt.grid(True)
plt.show()

# %%
# evaluate the model
print("Evaluating trained RNN in Closed-Loop Autoregressive for Size 8")
model.eval()

with torch.no_grad():
    continous_pred = []
    current_state = Z[0].to(device)

    # init hidden memory for all 20,000 steps
    h_k = torch.zeros(model.hidden_size, device=device)

    for k in range(len(U)):
        # get true input for this time step
        u_k = U[k].to(device)

        # combine current input with current force
        step_data = torch.cat((current_state, u_k))

        # forward pass this time step
        h_k = torch.tanh(h_k @ model.W_hh + step_data @ model.W_uh + model.b_h)
        next_state_pred = h_k @ model.W_hx + model.b_x

        # save this prediction
        continous_pred.append(next_state_pred)

        # feedback loop
        current_state = next_state_pred

    Y_pred_norm = torch.stack(continous_pred)
    # Convert to numpy and un-normalize
    Y_pred = Y_pred_norm.cpu().numpy() * z_std + z_mean

# Plotting Results
plt.figure(figsize=(12, 8))

# Plot Rel Pos (z1)
plt.subplot(2, 1, 1)
plt.plot(z_vals[:, 0], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 0], 'r--', label='RNN Prediction')
plt.ylabel('Relative Position z1 (x1 - x2) (m)')
plt.legend()
plt.grid(True)

# Plot Absolute Position of M2 (z3)
plt.subplot(2, 1, 2)
plt.plot(z_vals[:, 2], 'k-', label='Ground Truth')
plt.plot(Y_pred[:, 2], 'g--', label='RNN Prediction')
plt.ylabel('Absolute Position of M2 (m)')
plt.xlabel('Time Steps')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Evaluating trained RNN in Closed-Loop Autoregressive for Size 8
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
